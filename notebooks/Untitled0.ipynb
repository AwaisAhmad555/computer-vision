# %%
import numpy as np
import pandas as pd

# %%
list_1 = list([5,4,1])

array = np.array([[2,3,4],list_1])

print(array)
# Out:
# [[2 3 4]
#  [5 4 1]]

# %%
dataframe = pd.DataFrame(array,index=None)

print(dataframe)
# Out:
#    0  1  2
# 0  2  3  4
# 1  5  4  1
